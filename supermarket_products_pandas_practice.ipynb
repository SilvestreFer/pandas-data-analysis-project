# %% [markdown]
# <a href="https://colab.research.google.com/github/SilvestreFer/pandas-data-analysis-project/blob/main/supermarket_products_pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛒 **Supermarket Products Data — Pandas Practice**
#
# This notebook contains a small dataset of supermarket and fresh produce items, including their location, product name, and price.
# The main goal of this exercise is to practice **DataFrame manipulation in Pandas**, specifically removing rows and exploring how `drop()` works while working with real-world-like data.

# %%
import pandas as pd

# %% [markdown]
# ### **Creating the DataFrame**
#
# * The data consists of product prices from different locations.
# * Each row represents a product at a given location with its price.
# * Using a DataFrame allows easy manipulation and analysis with Pandas.

# %%
product_prices_df = pd.DataFrame([['Feira', 'Cebola', 2.5],
                        ['Mercado', 'Cebola', 1.99],
                        ['Supermercado', 'Cebola', 1.69],
                        ['Feira', 'Tomate', 4],
                        ['Mercado', 'Tomate', 3.29],
                        ['Supermercado', 'Tomate', 2.99],
                        ['Feira', 'Batata', 4.2],
                        ['Mercado', 'Batata', 3.99],
                        ['Supermercado', 'Batata', 3.69]],
                        columns = ['Local', 'Produto', 'Preço'])
product_prices_df
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
product_prices_df.drop([2, 5, 8], axis=0, inplace=True)

# %%
product_prices_df
# Out:
#      Local Produto  Preço
# 0    Feira  Cebola   2.50
# 1  Mercado  Cebola   1.99
# 3    Feira  Tomate   4.00
# 4  Mercado  Tomate   3.29
# 6    Feira  Batata   4.20
# 7  Mercado  Batata   3.99
